# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
## 下載檔案
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10972529949","type":"PushEvent","actor":{"id":1387516,"login":"papadop","display_login":"papadop","gravatar_id":"","url":"https://api.github.com/users/papadop","avatar_url":"https://avatars.githubusercontent.com/u/1387516?"},"repo":{"id":207300755,"name":"SED-Inria-Sophia/openmeeg","url":"https://api.github.com/repos/SED-Inria-Sophia/openmeeg"},"payload":{"push_id":4333986809,"size":1,"distinct_size":1,"ref":"refs/heads/develop","head":"fd734c6229874e53604603ec26bede8398fb9c01","before":"31eff986da817c58c2694c776f6c04fcf4aec87c","commits":[{"sha":"fd734c6229874e53604603ec26bede8398fb9c01","author":{"email":"Theodore.Papadopoulo@inria.fr","name":"Theodore Papadopoulo"},"message":"Minor correction.","distinct":true,"url":"https://api.github.com/repos/SED-Inria-Sophia/openmeeg/commits/fd734c6229874e53604603ec26bede8398fb9c01"}]},"public":true,"created_at":"2019-11-29T01:03:04Z","org":{"id":23495920,"login":"SED-Inria-Sophia","gravatar_id":"","url":"https://api.github.com/orgs/SED-Inria-Sophia","avatar_url":"https://avatars.githubusercontent.com/u/23495920?"}},{"id":"10972529948","type":"PushEvent","actor":{"id":18298473,"login":"ranggarifqi","display_login":"ranggarifqi","gravatar_id":"","url":"https://api.github.com/users/ranggarifqi","avatar_url":"https://avatars.githubusercontent.com/u/18298473?"},"repo":{"id":224623939,"name":"ranggarifqi/hapi-hotel-booking","url":"https://api.github.com/repos/ranggarifqi/hapi-hotel-booking"},"payload":{"push_id":4333986807,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"157ec917fbbde33f638ce631413414a235b3b274","before":"97b07c6fc4bfd41c3f62effae6c1fc622f970c4e","commits":[{"sha":"157ec917fbbde33f638ce631413414a235b3b274","author":{"email":"rangga.rifqi.pratama@gmail.com","name":"Rangga Rifqi Pratama"},"message":"Create multiple booking service","distinct":true,"url":"https://api.github.com/repos/ranggarifqi/hapi-hotel-booking/commits/157ec917fbbde33f638ce631413414a235b3b274"}]},"public":true,"created_at":"2019-11-29T01:03:04Z"},{"id":"10972529944","type":"IssueCommentEvent","actor":{"id":50908370,"login":"huchengze","display_login":"huchengze","gravatar_id":"","url":"https://api.github.com/users/huchengze","avatar_url":"https://avatars.githubusercontent.com/u/50908370?"},"repo":{"id":20580498,"name":"kubernetes/kubernetes","url":"https://api.github.com/repos/kubernetes/kubernetes"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/kubernetes/kubernetes/issues/85568","repository_url":"https://api.github.com/repos/kubernetes/kubernetes","labels_url":"https://api.github.com/repos/kubernetes/kubernetes/issues/85568/labels{/name}","comments_url":"https://api.github.com/repos/kubernetes/kubernetes/issues/85568/comments","events_url":"https://api.github.com/repos/kubernetes/kubernetes/issues/85568/events","html_url":"https://github.com/kubernetes/kubernetes/pull/85568","id":527527936,"node_id":"MDExOlB1bGxSZXF1ZXN0MzQ0Nzg4NjA2","number":85568,"title":"flexvolume_expand","user":{"login":"huchengze","id":50908370,"node_id":"MDQ6VXNlcjUwOTA4Mzcw","avatar_url":"https://avatars2.githubusercontent.com/u/50908370?v=4","gravatar_id":"","url":"https://api.github.com/users/huchengze","html_url":"https://github.com/huchengze","followers_url":"https://api.github.com/users/huchengze/followers","following_url":"https://api.github.com/users/huchengze/following{/other_user}","gists_url":"https://api.github.com/users/huchengze/gists{/gist_id}","starred_url":"https://api.github.com/users/huchengze/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/huchengze/subscriptions","organizations_url":"https://api.github.com/users/huchengze/orgs","repos_url":"https://api.github.com/users/huchengze/repos","events_url":"https://api.github.com/users/huchengze/events{/privacy}","received_events_url":"https://api.github.com/users/huchengze/received_events","type":"User","site_admin":false},"labels":[{"id":477397085,"node_id":"MDU6TGFiZWw0NzczOTcwODU=","url":"ht ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10972529949',
#   'type': 'PushEvent',
#   'actor': {'id': 1387516,
#    'login': 'papadop',
#    'display_login': 'papadop',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/papadop',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1387516?'},
#   'repo': {'id': 207300755,
#    'name': 'SED-Inria-Sophia/openmeeg',
#    'url': 'https://api.github.com/repos/SED-Inria-Sophia/openmeeg'},
#   'payload': {'push_id': 4333986809,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': 'fd734c6229874e53604603ec26bede8398fb9c01',
#    'before': '31eff986da817c58c2694c776f6c04fcf4aec87c',
#    'commits': [{'sha': 'fd734c6229874e53604603ec26bede8398fb9c01',
#      'author': {'email': 'Theodore.Papadopoulo@inria.fr',
#       'name': 'Theodore Papadopoulo'},
#      'message': 'Minor correction.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SED-Inria-Sophia/openmeeg/commits/fd734c6229874e53604603ec26bede8398fb9c01'}]},
#   'public': True,
#   'created_at': '2019-11-29T01:03:04Z',
#   'org': {'id': 23495920,
#    'login': 'SED-Inria-Sophia',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SED-Inria-Sophia',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23495920?'}},
#  {'id': '10972529948',
#   'type': 'PushEvent',
#   'actor': {'id': 18298473,
#    'login': 'ranggarifqi',
#    'display_login': 'ranggarifqi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ranggarifqi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18298473?'},
#   'repo': {'id': 224623939,
#    'name': 'ranggarifqi/hapi-hotel-booking',
#    'url': 'https://api.github.com/repos/ranggarifqi/hapi-hotel-booking'},
#   'payload': {'push_id': 4333986807,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '157ec917fbbde33f638ce631413414a235b3b274',
#    'before': '97b07c6fc4bfd41c3f62effae6c1fc622f970c4e',
#    'commits': [{'sha': '157ec917fbbde33f638ce631413414a235b3b274',
#      'author': {'email': 'rangga.rifqi.pratama@gmail.com',
#       'name': 'Rangga Rifqi Pratama'},
#      'message': 'Create multiple booking service',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ranggarifqi/hapi-hotel-booking/commits/157ec917fbbde33f638ce631413414a235b3b274'}]},
#   'public': True,
#   'created_at': '2019-11-29T01:03:04Z'},
#  {'id': '10972529944',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 50908370,
#    'login': 'huchengze',
#    'display_login': 'huchengze',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/huchengze',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50908370?'},
#   'repo': {'id': 20580498,
#    'name': 'kubernetes/kubernetes',
#    'url': 'https://api.github.com/repos/kubernetes/kubernetes'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/85568',
#     'repository_url': 'https://api.github.com/repos/kubernetes/kubernetes',
#     'labels_url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/85568/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/85568/comments',
#     'events_url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/85568/events',
#     'html_url': 'https://github.com/kubernetes/kubernetes/pull/85568',
#     'id': 527527936,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ0Nzg4NjA2',
#     'number': 85568,
#     'title': 'flexvolume_expand',
#     'user': {'login': 'huchengze',
#      'id': 50908370,
#      'node_id': 'MDQ6VXNlcjUwOTA4Mzcw',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/50908370?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/huchengze',
#      'html_url': 'https://github.com/huchengze',
#      'followers_url': 'https://api.github.com/users/huchengze/followers',
#      'following_url': 'https://api.github.com/users/huchengze/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/huchengze/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/huchengze/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/huchengze/subscriptions',
#      'organizations_url': 'https://api.github.com/users/huchengze/orgs',
#      'repos_url': 'https://api.github.com/users/huchengze/repos',
#      'events_url': 'https://api.github.com/users/huchengze/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/huchengze/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 477397085,
#       'node_id': 'MDU6TGFiZWw0NzczOTcwODU=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/cncf-cla:%20no',
#       'name': 'cncf-cla: no',
#       'color': 'e11d21',
#       'default': False,
#       'description': "Indicates the PR's author has not signed the CNCF CLA."},
#      {'id': 680154135,
#       'node_id': 'MDU6TGFiZWw2ODAxNTQxMzU=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/do-not-merge/cherry-pick-not-approved',
#       'name': 'do-not-merge/cherry-pick-not-approved',
#       'color': 'e11d21',
#       'default': False,
#       'description': 'Indicates that a PR is not yet approved to merge into a release branch.'},
#      {'id': 105146071,
#       'node_id': 'MDU6TGFiZWwxMDUxNDYwNzE=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/kind/bug',
#       'name': 'kind/bug',
#       'color': 'e11d21',
#       'default': False,
#       'description': 'Categorizes issue or PR as related to a bug.'},
#      {'id': 1111992057,
#       'node_id': 'MDU6TGFiZWwxMTExOTkyMDU3',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/needs-priority',
#       'name': 'needs-priority',
#       'color': 'ededed',
#       'default': False,
#       'description': 'Indicates a PR lacks a `priority/foo` label and requires one.'},
#      {'id': 1086787260,
#       'node_id': 'MDU6TGFiZWwxMDg2Nzg3MjYw',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/ok-to-test',
#       'name': 'ok-to-test',
#       'color': '15dd18',
#       'default': False,
#       'description': 'Indicates a non-member PR verified by an org member that is safe to test.'},
#      {'id': 200149833,
#       'node_id': 'MDU6TGFiZWwyMDAxNDk4MzM=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/release-note',
#       'name': 'release-note',
#       'color': 'c2e0c6',
#       'default': False,
#       'description': 'Denotes a PR that will be considered when it comes time to generate release notes.'},
#      {'id': 404091735,
#       'node_id': 'MDU6TGFiZWw0MDQwOTE3MzU=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/sig/apps',
#       'name': 'sig/apps',
#       'color': 'd2b48c',
#       'default': False,
#       'description': 'Categorizes an issue or PR as relevant to sig-apps.'},
#      {'id': 169428334,
#       'node_id': 'MDU6TGFiZWwxNjk0MjgzMzQ=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/sig/storage',
#       'name': 'sig/storage',
#       'color': 'd2b48c',
#       'default': False,
#       'description': 'Categorizes an issue or PR as relevant to sig-storage.'},
#      {'id': 253450793,
#       'node_id': 'MDU6TGFiZWwyNTM0NTA3OTM=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/size/XS',
#       'name': 'size/XS',
#       'color': '009900',
#       'default': False,
#       'description': 'Denotes a PR that changes 0-9 lines, ignoring generated files.'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'sttts',
#      'id': 730123,
#      'node_id': 'MDQ6VXNlcjczMDEyMw==',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/730123?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sttts',
#      'html_url': 'https://github.com/sttts',
#      'followers_url': 'https://api.github.com/users/sttts/followers',
#      'following_url': 'https://api.github.com/users/sttts/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sttts/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sttts/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sttts/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sttts/orgs',
#      'repos_url': 'https://api.github.com/users/sttts/repos',
#      'events_url': 'https://api.github.com/users/sttts/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sttts/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'gnufied',
#       'id': 278,
#       'node_id': 'MDQ6VXNlcjI3OA==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/278?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gnufied',
#       'html_url': 'https://github.com/gnufied',
#       'followers_url': 'https://api.github.com/users/gnufied/followers',
#       'following_url': 'https://api.github.com/users/gnufied/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gnufied/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gnufied/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gnufied/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gnufied/orgs',
#       'repos_url': 'https://api.github.com/users/gnufied/repos',
#       'events_url': 'https://api.github.com/users/gnufied/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gnufied/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'sttts',
#       'id': 730123,
#       'node_id': 'MDQ6VXNlcjczMDEyMw==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/730123?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/sttts',
#       'html_url': 'https://github.com/sttts',
#       'followers_url': 'https://api.github.com/users/sttts/followers',
#       'following_url': 'https://api.github.com/users/sttts/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/sttts/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/sttts/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/sttts/subscriptions',
#       'organizations_url': 'https://api.github.com/users/sttts/orgs',
#       'repos_url': 'https://api.github.com/users/sttts/repos',
#       'events_url': 'https://api.github.com/users/sttts/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/sttts/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'jsafrane',
#       'id': 1745006,
#       'node_id': 'MDQ6VXNlcjE3NDUwMDY=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/1745006?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jsafrane',
#       'html_url': 'https://github.com/jsafrane',
#       'followers_url': 'https://api.github.com/users/jsafrane/followers',
#       'following_url': 'https://api.github.com/users/jsafrane/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jsafrane/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jsafrane/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jsafrane/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jsafrane/orgs',
#       'repos_url': 'https://api.github.com/users/jsafrane/repos',
#       'events_url': 'https://api.github.com/users/jsafrane/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jsafrane/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'chakri-nelluri',
#       'id': 9920367,
#       'node_id': 'MDQ6VXNlcjk5MjAzNjc=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/9920367?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/chakri-nelluri',
#       'html_url': 'https://github.com/chakri-nelluri',
#       'followers_url': 'https://api.github.com/users/chakri-nelluri/followers',
#       'following_url': 'https://api.github.com/users/chakri-nelluri/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/chakri-nelluri/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/chakri-nelluri/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/chakri-nelluri/subscriptions',
#       'organizations_url': 'https://api.github.com/users/chakri-nelluri/orgs',
#       'repos_url': 'https://api.github.com/users/chakri-nelluri/repos',
#       'events_url': 'https://api.github.com/users/chakri-nelluri/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/chakri-nelluri/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': {'url': 'https://api.github.com/repos/kubernetes/kubernetes/milestones/41',
#      'html_url': 'https://github.com/kubernetes/kubernetes/milestone/41',
#      'labels_url': 'https://api.github.com/repos/kubernetes/kubernetes/milestones/41/labels',
#      'id': 3751947,
#      'node_id': 'MDk6TWlsZXN0b25lMzc1MTk0Nw==',
#      'number': 41,
#      'title': 'v1.14',
#      'description': '',
#      'creator': {'login': 'idealhack',
#       'id': 408385,
#       'node_id': 'MDQ6VXNlcjQwODM4NQ==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/408385?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/idealhack',
#       'html_url': 'https://github.com/idealhack',
#       'followers_url': 'https://api.github.com/users/idealhack/followers',
#       'following_url': 'https://api.github.com/users/idealhack/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/idealhack/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/idealhack/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/idealhack/subscriptions',
#       'organizations_url': 'https://api.github.com/users/idealhack/orgs',
#       'repos_url': 'https://api.github.com/users/idealhack/repos',
#       'events_url': 'https://api.github.com/users/idealhack/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/idealhack/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 11,
#      'closed_issues': 582,
#      'state': 'open',
#      'created_at': '2018-10-19T11:05:25Z',
#      'updated_at': '2019-11-27T22:57:07Z',
#      'due_on': None,
#      'closed_at': None},
#     'comments': 9,
#     'created_at': '2019-11-23T08:21:57Z',
#     'updated_at': '2019-11-29T01:03:04Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/kubernetes/kubernetes/pulls/85568',
#      'html_url': 'https://github.com/kubernetes/kubernetes/pull/85568',
#      'diff_url': 'https://github.com/kubernetes/kubernetes/pull/85568.diff',
#      'patch_url': 'https://github.com/kubernetes/kubernetes/pull/85568.patch'},
#     'body': '/kind bug\r\n\r\nFixes #85504\r\n\r\n```release-note\r\nfix a bug in PVC resize when using flexvolume.\r\n```\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/comments/559627712',
#     'html_url': 'https://github.com/kubernetes/kubernetes/pull/85568#issuecomment-559627712',
#     'issue_url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/85568',
#     'id': 559627712,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTYyNzcxMg==',
#     'user': {'login': 'huchengze',
#      'id': 50908370,
#      'node_id': 'MDQ6VXNlcjUwOTA4Mzcw',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/50908370?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/huchengze',
#      'html_url': 'https://github.com/huchengze',
#      'followers_url': 'https://api.github.com/users/huchengze/followers',
#      'following_url': 'https://api.github.com/users/huchengze/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/huchengze/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/huchengze/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/huchengze/subscriptions',
#      'organizations_url': 'https://api.github.com/users/huchengze/orgs',
#      'repos_url': 'https://api.github.com/users/huchengze/repos',
#      'events_url': 'https://api.github.com/users/huchengze/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/huchengze/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-29T01:03:04Z',
#     'updated_at': '2019-11-29T01:03:04Z',
#     'author_association': 'NONE',
#     'body': '/check-cla'}},
#   'public': True,
#   'created_at': '2019-11-29T01:03:04Z',
#   'org': {'id': 13629408,
#    'login': 'kubernetes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kubernetes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13629408?'}},
#  {'id': '10972529942',
#   'type': 'PushEvent',
#   'actor': {'id': 43686996,
#    'login': 'MichaMichael',
#    'display_login': 'MichaMichael',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MichaMichael',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43686996?'},
#   'repo': {'id': 224557537,
#    'name': 'MichaMichael/ka-wedding',
#    'url': 'https://api.github.com/repos/MichaMichael/ka-wedding'},
#   'payload': {'push_id': 4333986802,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '03fe97c733b2206b23ebb3d44edfbe205fc16977',
#    'before': 'bd6efcde1c2b27025bc581311ca50962cd426702',
#    'commits': [{'sha': '03fe97c733b2206b23ebb3d44edfbe205fc16977',
#      'author': {'email': 'kogan-misha@rambler.ru', 'name': 'michamichael'},
#      'message': 'Changed simple images to real',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MichaMichael/ka-wedding/commits/03fe97c733b2206b23ebb3d44edfbe205fc16977'}]},
#   'public': True,
#   'created_at': '2019-11-29T01:03:04Z'},
#  {'id': '10972529943',
#   'type': 'PushEvent',
#   'actor': {'id': 4938650,
#    'login': 'Unpublished',
#    'display_login': 'Unpublished',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Unpublished',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4938650?'},
#   'repo': {'id': 124305515,
#    'name': 'Unpublished/GithubTrending',
#    'url': 'https://api.github.com/repos/Unpublished/GithubTrending'},
#   'payload': {'push_id': 4333986806,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/trends',
#    'head': 'ed2e02d140505391bf4fa2aed49d9d900a248489',
#    'before': '1529e5834cdcf619879a9d2d0d053fe7ebffbbd4',
#    'commits': [{'sha': 'ed2e02d140505391bf4fa2aed49d9d900a248489',
#      'author': {'email': 'deploy@travis-ci.org',
#       'name': 'Deployment Bot (from Travis CI)'},
#      'message': 'Deploy Unpublished/GithubTrending to github.com/Unpublished/GithubTrending.git:trends',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Unpublished/GithubTrending/commits/ed2e02d140505391bf4fa2aed49d9d900a248489'}]},
#   'public': True,
#   'created_at': '2019-11-29T01:03:04Z'},
#  {'id': '10972529945',
#   'type': 'PushEvent',
#   'actor': {'id': 22635539,
#    'login': 'context-machine',
#    'display_login': 'context-machine',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/context-machine',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22635539?'},
#   'repo': {'id': 87076856,
#    'name': 'offstream-news/public',
#    'url': 'https://api.github.com/repos/offstream-news/public'},
#   'payload': {'push_id': 4333986801,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5429bf85e273418ae2c1d4581aa465254c52d89b',
#    'before': 'bd0a6dd44d86f985eba56c221e2c5f0b16784a7a',
#    'commits': [{'sha': '5429bf85e273418ae2c1d4581aa465254c52d89b',
#      'author': {'email': 'editor@thecontext.net',
#       'name': 'the Context Machine'},
#      'message': 'News update on Fri, 29 Nov 2019 01:02:14 UTC',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/offstream-news/public/commits/5429bf85e273418ae2c1d4581aa465254c52d89b'}]},
#   'public': True,
#   'created_at': '2019-11-29T01:03:04Z',
#   'org': {'id': 52006851,
#    'login': 'offstream-news',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/offstream-news',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52006851?'}},
#  {'id': '10972529939',
#   'type': 'PushEvent',
#   'actor': {'id': 54559060,
#    'login': 'charles-tech',
#    'display_login': 'charles-tech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/charles-tech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54559060?'},
#   'repo': {'id': 208357249,
#    'name': 'charles-tech/Eureka',
#    'url': 'https://api.github.com/repos/charles-tech/Eureka'},
#   'payload': {'push_id': 4333986804,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/OrientadoObejeto',
#    'head': '842c80a45bdc9dec7c14270e4e728daa6d3ea54f',
#    'before': 'cde110b2b9ea63925ef116b6c2b1b17c5bb27cc1',
#    'commits': [{'sha': '842c80a45bdc9dec7c14270e4e728daa6d3ea54f',
#      'author': {'email': 'charles.miranda@alunos.sc.senac.br',
#       'name': 'CHARLES FERNANDO DE MIRANDA'},
#      'message': 'Funcionando',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/charles-tech/Eureka/commits/842c80a45bdc9dec7c14270e4e728daa6d3ea54f'}]},
#   'public': True,
#   'created_at': '2019-11-29T01:03:04Z'},
#  {'id': '10972529938',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 6393603,
#    'login': 'MathyV',
#    'display_login': 'MathyV',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MathyV',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6393603?'},
#   'repo': {'id': 40499714,
#    'name': 'gentoo/gentoo',
#    'url': 'https://api.github.com/repos/gentoo/gentoo'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/gentoo/gentoo/issues/13794',
#     'repository_url': 'https://api.github.com/repos/gentoo/gentoo',
#     'labels_url': 'https://api.github.com/repos/gentoo/gentoo/issues/13794/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/gentoo/gentoo/issues/13794/comments',
#     'events_url': 'https://api.github.com/repos/gentoo/gentoo/issues/13794/events',
#     'html_url': 'https://github.com/gentoo/gentoo/pull/13794',
#     'id': 530111953,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2ODYxNDA5',
#     'number': 13794,
#     'title': 'media-sound/spotify: remove gconf dependency',
#     'user': {'login': 'MathyV',
#      'id': 6393603,
#      'node_id': 'MDQ6VXNlcjYzOTM2MDM=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/6393603?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/MathyV',
#      'html_url': 'https://github.com/MathyV',
#      'followers_url': 'https://api.github.com/users/MathyV/followers',
#      'following_url': 'https://api.github.com/users/MathyV/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MathyV/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/MathyV/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MathyV/subscriptions',
#      'organizations_url': 'https://api.github.com/users/MathyV/orgs',
#      'repos_url': 'https://api.github.com/users/MathyV/repos',
#      'events_url': 'https://api.github.com/users/MathyV/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/MathyV/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-11-29T01:02:42Z',
#     'updated_at': '2019-11-29T01:03:04Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/gentoo/gentoo/pulls/13794',
#      'html_url': 'https://github.com/gentoo/gentoo/pull/13794',
#      'diff_url': 'https://github.com/gentoo/gentoo/pull/13794.diff',
#      'patch_url': 'https://github.com/gentoo/gentoo/pull/13794.patch'},
#     'body': "It's actually not used anymore by the binary\r\n\r\nCloses: https://bugs.gentoo.org/701438\r\nSigned-off-by: Mathy Vanvoorden <mathy@vanvoorden.be>"},
#    'comment': {'url': 'https://api.github.com/repos/gentoo/gentoo/issues/comments/559627711',
#     'html_url': 'https://github.com/gentoo/gentoo/pull/13794#issuecomment-559627711',
#     'issue_url': 'https://api.github.com/repos/gentoo/gentoo/issues/13794',
#     'id': 559627711,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTYyNzcxMQ==',
#     'user': {'login': 'MathyV',
#      'id': 6393603,
#      'node_id': 'MDQ6VXNlcjYzOTM2MDM=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/6393603?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/MathyV',
#      'html_url': 'https://github.com/MathyV',
#      'followers_url': 'https://api.github.com/users/MathyV/followers',
#      'following_url': 'https://api.github.com/users/MathyV/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MathyV/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/MathyV/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MathyV/subscriptions',
#      'organizations_url': 'https://api.github.com/users/MathyV/orgs',
#      'repos_url': 'https://api.github.com/users/MathyV/repos',
#      'events_url': 'https://api.github.com/users/MathyV/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/MathyV/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-29T01:03:04Z',
#     'updated_at': '2019-11-29T01:03:04Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "Wasn't sure if it needed a revision bump, let me know if should resubmit"}},
#   'public': True,
#   'created_at': '2019-11-29T01:03:04Z',
#   'org': {'id': 52242,
#    'login': 'gentoo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/gentoo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52242?'}},
#  {'id': '10972529929',
#   'type': 'PushEvent',
#   'actor': {'id': 42068596,
#    'login': 'DavidCjr',
#    'display_login': 'DavidCjr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DavidCjr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42068596?'},
#   'repo': {'id': 224298129,
#    'name': 'DavidCjr/projeto-curso-git',
#    'url': 'https://api.github.com/repos/DavidCjr/projeto-curso-git'},
#   'payload': {'push_id': 4333986795,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/Implementações',
#    'head': 'e089ad5b0d4887b575619a5973399dcffb8fbbab',
#    'before': '0c1d95e3484b3b166c716d5d6032a7a8f3d31026',
#    'commits': [{'sha': 'e089ad5b0d4887b575619a5973399dcffb8fbbab',
#      'author': {'email': 'david.cjr@gmail.com', 'name': 'David'},
#      'message': 'Implementação do Formulário Caixa',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DavidCjr/projeto-curso-git/commits/e089ad5b0d4887b575619a5973399dcffb8fbbab'}]},
#   'public': True,
#   'created_at': '2019-11-29T01:03:03Z'},
#  {'id': '10972529928',
#   'type': 'PushEvent',
#   'actor': {'id': 11724550,
#    'login': 'wcadena',
#    'display_login': 'wcadena',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wcadena',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11724550?'},
#   'repo': {'id': 224561376,
#    'name': 'wcadena/ecuatask-desktop',
#    'url': 'https://api.github.com/repos/wcadena/ecuatask-desktop'},
#   'payload': {'push_id': 4333986793,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6a095e84a23b47f47fde3e173745a5cf05d24c69',
#    'before': 'ba9eed7c00dc2358f2fad795687e04c8e7b4dfc6',
#    'commits': [{'sha': '6a095e84a23b47f47fde3e173745a5cf05d24c69',
#      'author': {'email': 'wcadena@outlook.com',
#       'name': 'Wágner Alexánder Cadena Lastra'},
#      'message': 'se mejora link',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wcadena/ecuatask-desktop/commits/6a095e84a23b47f47fde3e173745a5cf05d24c69'}]},
#   'public': True,
#   'created_at': '2019-11-29T01:03:03Z'},
#  {'id': '10972529927',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 2576432,
#    'login': 'RodneyBaker',
#    'display_login': 'RodneyBaker',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RodneyBaker',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2576432?'},
#   'repo': {'id': 54221232,
#    'name': 'opentoonz/opentoonz',
#    'url': 'https://api.github.com/repos/opentoonz/opentoonz'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/opentoonz/opentoonz/issues/2907',
#     'repository_url': 'https://api.github.com/repos/opentoonz/opentoonz',
#     'labels_url': 'https://api.github.com/repos/opentoonz/opentoonz/issues/2907/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/opentoonz/opentoonz/issues/2907/comments',
#     'events_url': 'https://api.github.com/repos/opentoonz/opentoonz/issues/2907/events',
#     'html_url': 'https://github.com/opentoonz/opentoonz/pull/2907',
#     'id': 529977960,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2NzU0OTc3',
#     'number': 2907,
#     'title': '(WIP) Add Create Blank Frame command',
#     'user': {'login': 'manongjohn',
#      'id': 19245851,
#      'node_id': 'MDQ6VXNlcjE5MjQ1ODUx',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/19245851?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/manongjohn',
#      'html_url': 'https://github.com/manongjohn',
#      'followers_url': 'https://api.github.com/users/manongjohn/followers',
#      'following_url': 'https://api.github.com/users/manongjohn/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/manongjohn/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/manongjohn/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/manongjohn/subscriptions',
#      'organizations_url': 'https://api.github.com/users/manongjohn/orgs',
#      'repos_url': 'https://api.github.com/users/manongjohn/repos',
#      'events_url': 'https://api.github.com/users/manongjohn/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/manongjohn/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 8,
#     'created_at': '2019-11-28T15:35:46Z',
#     'updated_at': '2019-11-29T01:03:03Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'pull_request': {'url': 'https://api.github.com/repos/opentoonz/opentoonz/pulls/2907',
#      'html_url': 'https://github.com/opentoonz/opentoonz/pull/2907',
#      'diff_url': 'https://github.com/opentoonz/opentoonz/pull/2907.diff',
#      'patch_url': 'https://github.com/opentoonz/opentoonz/pull/2907.patch'},
#     'body': 'Requested by a few users (and questioned why there is no command for it  by many others), this PR adds a command to allow a user to create a blank frame.\r\n\r\nThis command only works on the Xsheet/Timeline and factors into account Autocreation mode and Auto-stretch settings.\r\n\r\nIf Autocreation mode is `Disabled`, the command will temporarily change the setting to `Enabled` to create the frame according to those settings and then disables that preference again.\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/opentoonz/opentoonz/issues/comments/559627710',
#     'html_url': 'https://github.com/opentoonz/opentoonz/pull/2907#issuecomment-559627710',
#     'issue_url': 'https://api.github.com/repos/opentoonz/opentoonz/issues/2907',
#     'id': 559627710,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTYyNzcxMA==',
#     'user': {'login': 'RodneyBaker',
#      'id': 2576432,
#      'node_id': 'MDQ6VXNlcjI1NzY0MzI=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/2576432?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/RodneyBaker',
#      'html_url': 'https://github.com/RodneyBaker',
#      'followers_url': 'https://api.github.com/users/RodneyBaker/followers',
#      'following_url': 'https://api.github.com/users/RodneyBaker/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/RodneyBaker/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/RodneyBaker/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/RodneyBaker/subscriptions',
#      'organizations_url': 'https://api.github.com/users/RodneyBaker/orgs',
#      'repos_url': 'https://api.github.com/users/RodneyBaker/repos',
#      'events_url': 'https://api.github.com/users/RodneyBaker/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/RodneyBaker/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-29T01:03:03Z',
#     'updated_at': '2019-11-29T01:03:03Z',
#     'author_association': 'COLLABORATOR',
#     'body': "I'd think key combinations using E for things might be best reserved for future features/enhancements related to Erasing and B for things related to Brushes.  This mirroring current shortcut keys E (Erase) and B (Brush).\r\n\r\n\r\n"}},
#   'public': True,
#   'created_at': '2019-11-29T01:03:03Z',
#   'org': {'id': 15189838,
#    'login': 'opentoonz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/opentoonz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15189838?'}},
#  {'id': '10972529924',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 56313800,
#    'login': 'AminAmani83',
#    'display_login': 'AminAmani83',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AminAmani83',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56313800?'},
#   'repo': {'id': 224529155,
#    'name': 'AminAmani83/Class5DB',
#    'url': 'https://api.github.com/repos/AminAmani83/Class5DB'},
#   'payload': {'action': 'closed',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/AminAmani83/Class5DB/pulls/1',
#     'id': 346861372,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2ODYxMzcy',
#     'html_url': 'https://github.com/AminAmani83/Class5DB/pull/1',
#     'diff_url': 'https://github.com/AminAmani83/Class5DB/pull/1.diff',
#     'patch_url': 'https://github.com/AminAmani83/Class5DB/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/AminAmani83/Class5DB/issues/1',
#     'number': 1,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Dev loc',
#     'user': {'login': 'AminAmani83',
#      'id': 56313800,
#      'node_id': 'MDQ6VXNlcjU2MzEzODAw',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/56313800?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/AminAmani83',
#      'html_url': 'https://github.com/AminAmani83',
#      'followers_url': 'https://api.github.com/users/AminAmani83/followers',
#      'following_url': 'https://api.github.com/users/AminAmani83/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/AminAmani83/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/AminAmani83/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/AminAmani83/subscriptions',
#      'organizations_url': 'https://api.github.com/users/AminAmani83/orgs',
#      'repos_url': 'https://api.github.com/users/AminAmani83/repos',
#      'events_url': 'https://api.github.com/users/AminAmani83/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/AminAmani83/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'pull it!',
#     'created_at': '2019-11-29T01:02:20Z',
#     'updated_at': '2019-11-29T01:03:03Z',
#     'closed_at': '2019-11-29T01:03:03Z',
#     'merged_at': '2019-11-29T01:03:03Z',
#     'merge_commit_sha': 'c729e225bbac43290f17ab3f2e140f372cf0e2ec',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/AminAmani83/Class5DB/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/AminAmani83/Class5DB/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/AminAmani83/Class5DB/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/AminAmani83/Class5DB/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/AminAmani83/Class5DB/statuses/05ac43e6651307431b8b6e24e3212268f44677d6',
#     'head': {'label': 'AminAmani83:dev-loc',
#      'ref': 'dev-loc',
#      'sha': '05ac43e6651307431b8b6e24e3212268f44677d6',
#      'user': {'login': 'AminAmani83',
#       'id': 56313800,
#       'node_id': 'MDQ6VXNlcjU2MzEzODAw',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/56313800?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AminAmani83',
#       'html_url': 'https://github.com/AminAmani83',
#       'followers_url': 'https://api.github.com/users/AminAmani83/followers',
#       'following_url': 'https://api.github.com/users/AminAmani83/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AminAmani83/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AminAmani83/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AminAmani83/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AminAmani83/orgs',
#       'repos_url': 'https://api.github.com/users/AminAmani83/repos',
#       'events_url': 'https://api.github.com/users/AminAmani83/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AminAmani83/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 224529155,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ1MjkxNTU=',
#       'name': 'Class5DB',
#       'full_name': 'AminAmani83/Class5DB',
#       'private': False,
#       'owner': {'login': 'AminAmani83',
#        'id': 56313800,
#        'node_id': 'MDQ6VXNlcjU2MzEzODAw',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/56313800?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/AminAmani83',
#        'html_url': 'https://github.com/AminAmani83',
#        'followers_url': 'https://api.github.com/users/AminAmani83/followers',
#        'following_url': 'https://api.github.com/users/AminAmani83/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/AminAmani83/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/AminAmani83/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/AminAmani83/subscriptions',
#        'organizations_url': 'https://api.github.com/users/AminAmani83/orgs',
#        'repos_url': 'https://api.github.com/users/AminAmani83/repos',
#        'events_url': 'https://api.github.com/users/AminAmani83/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/AminAmani83/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/AminAmani83/Class5DB',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/AminAmani83/Class5DB',
#       'forks_url': 'https://api.github.com/repos/AminAmani83/Class5DB/forks',
#       'keys_url': 'https://api.github.com/repos/AminAmani83/Class5DB/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/AminAmani83/Class5DB/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/AminAmani83/Class5DB/teams',
#       'hooks_url': 'https://api.github.com/repos/AminAmani83/Class5DB/hooks',
#       'issue_events_url': 'https://api.github.com/repos/AminAmani83/Class5DB/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/AminAmani83/Class5DB/events',
#       'assignees_url': 'https://api.github.com/repos/AminAmani83/Class5DB/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/AminAmani83/Class5DB/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/AminAmani83/Class5DB/tags',
#       'blobs_url': 'https://api.github.com/repos/AminAmani83/Class5DB/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/AminAmani83/Class5DB/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/AminAmani83/Class5DB/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/AminAmani83/Class5DB/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/AminAmani83/Class5DB/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/AminAmani83/Class5DB/languages',
#       'stargazers_url': 'https://api.github.com/repos/AminAmani83/Class5DB/stargazers',
#       'contributors_url': 'https://api.github.com/repos/AminAmani83/Class5DB/contributors',
#       'subscribers_url': 'https://api.github.com/repos/AminAmani83/Class5DB/subscribers',
#       'subscription_url': 'https://api.github.com/repos/AminAmani83/Class5DB/subscription',
#       'commits_url': 'https://api.github.com/repos/AminAmani83/Class5DB/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/AminAmani83/Class5DB/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/AminAmani83/Class5DB/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/AminAmani83/Class5DB/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/AminAmani83/Class5DB/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/AminAmani83/Class5DB/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/AminAmani83/Class5DB/merges',
#       'archive_url': 'https://api.github.com/repos/AminAmani83/Class5DB/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/AminAmani83/Class5DB/downloads',
#       'issues_url': 'https://api.github.com/repos/AminAmani83/Class5DB/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/AminAmani83/Class5DB/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/AminAmani83/Class5DB/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/AminAmani83/Class5DB/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/AminAmani83/Class5DB/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/AminAmani83/Class5DB/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/AminAmani83/Class5DB/deployments',
#       'created_at': '2019-11-27T22:42:44Z',
#       'updated_at': '2019-11-27T23:14:03Z',
#       'pushed_at': '2019-11-29T01:03:03Z',
#       'git_url': 'git://github.com/AminAmani83/Class5DB.git',
#       'ssh_url': 'git@github.com:AminAmani83/Class5DB.git',
#       'clone_url': 'https://github.com/AminAmani83/Class5DB.git',
#       'svn_url': 'https://github.com/AminAmani83/Class5DB',
#       'homepage': None,
#       'size': 9,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'AminAmani83:master',
#      'ref': 'master',
#      'sha': '63f26a8cd471b7d2837de325ba73a746830f5b03',
#      'user': {'login': 'AminAmani83',
#       'id': 56313800,
#       'node_id': 'MDQ6VXNlcjU2MzEzODAw',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/56313800?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AminAmani83',
#       'html_url': 'https://github.com/AminAmani83',
#       'followers_url': 'https://api.github.com/users/AminAmani83/followers',
#       'following_url': 'https://api.github.com/users/AminAmani83/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AminAmani83/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AminAmani83/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AminAmani83/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AminAmani83/orgs',
#       'repos_url': 'https://api.github.com/users/AminAmani83/repos',
#       'events_url': 'https://api.github.com/users/AminAmani83/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AminAmani83/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 224529155,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ1MjkxNTU=',
#       'name': 'Class5DB',
#       'full_name': 'AminAmani83/Class5DB',
#       'private': False,
#       'owner': {'login': 'AminAmani83',
#        'id': 56313800,
#        'node_id': 'MDQ6VXNlcjU2MzEzODAw',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/56313800?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/AminAmani83',
#        'html_url': 'https://github.com/AminAmani83',
#        'followers_url': 'https://api.github.com/users/AminAmani83/followers',
#        'following_url': 'https://api.github.com/users/AminAmani83/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/AminAmani83/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/AminAmani83/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/AminAmani83/subscriptions',
#        'organizations_url': 'https://api.github.com/users/AminAmani83/orgs',
#        'repos_url': 'https://api.github.com/users/AminAmani83/repos',
#        'events_url': 'https://api.github.com/users/AminAmani83/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/AminAmani83/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/AminAmani83/Class5DB',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/AminAmani83/Class5DB',
#       'forks_url': 'https://api.github.com/repos/AminAmani83/Class5DB/forks',
#       'keys_url': 'https://api.github.com/repos/AminAmani83/Class5DB/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/AminAmani83/Class5DB/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/AminAmani83/Class5DB/teams',
#       'hooks_url': 'https://api.github.com/repos/AminAmani83/Class5DB/hooks',
#       'issue_events_url': 'https://api.github.com/repos/AminAmani83/Class5DB/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/AminAmani83/Class5DB/events',
#       'assignees_url': 'https://api.github.com/repos/AminAmani83/Class5DB/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/AminAmani83/Class5DB/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/AminAmani83/Class5DB/tags',
#       'blobs_url': 'https://api.github.com/repos/AminAmani83/Class5DB/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/AminAmani83/Class5DB/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/AminAmani83/Class5DB/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/AminAmani83/Class5DB/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/AminAmani83/Class5DB/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/AminAmani83/Class5DB/languages',
#       'stargazers_url': 'https://api.github.com/repos/AminAmani83/Class5DB/stargazers',
#       'contributors_url': 'https://api.github.com/repos/AminAmani83/Class5DB/contributors',
#       'subscribers_url': 'https://api.github.com/repos/AminAmani83/Class5DB/subscribers',
#       'subscription_url': 'https://api.github.com/repos/AminAmani83/Class5DB/subscription',
#       'commits_url': 'https://api.github.com/repos/AminAmani83/Class5DB/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/AminAmani83/Class5DB/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/AminAmani83/Class5DB/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/AminAmani83/Class5DB/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/AminAmani83/Class5DB/contents/{+path}',
# ...
#   'public': True,
#   'created_at': '2019-11-29T01:03:01Z',
#   'org': {'id': 22494209,
#    'login': 'PennyDreadfulMTG',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PennyDreadfulMTG',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22494209?'}},
#  {'id': '10972529838',
#   'type': 'PushEvent',
#   'actor': {'id': 34057106,
#    'login': 'ibrahimjad',
#    'display_login': 'ibrahimjad',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ibrahimjad',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34057106?'},
#   'repo': {'id': 224751831,
#    'name': 'ibrahimjad/bilkabot_config',
#    'url': 'https://api.github.com/repos/ibrahimjad/bilkabot_config'},
#   'payload': {'push_id': 4333986750,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e68813c81c05eba4db244f6aff58a7addb431cf1',
#    'before': '1c5c0a6b4b7e336c2b45b9be701608c66156d30b',
#    'commits': [{'sha': 'e68813c81c05eba4db244f6aff58a7addb431cf1',
#      'author': {'email': 'ibrahim.jad@outlook.dk', 'name': 'Ibrahim J. Masri'},
#      'message': 'Config without camera',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ibrahimjad/bilkabot_config/commits/e68813c81c05eba4db244f6aff58a7addb431cf1'}]},
#   'public': True,
#   'created_at': '2019-11-29T01:03:01Z'},
#  {'id': '10972529836',
#   'type': 'IssuesEvent',
#   'actor': {'id': 23072004,
#    'login': 'vorpal-buildbot',
#    'display_login': 'vorpal-buildbot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vorpal-buildbot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23072004?'},
#   'repo': {'id': 112403149,
#    'name': 'PennyDreadfulMTG/perf-reports',
#    'url': 'https://api.github.com/repos/PennyDreadfulMTG/perf-reports'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/PennyDreadfulMTG/perf-reports/issues/52599',
#     'repository_url': 'https://api.github.com/repos/PennyDreadfulMTG/perf-reports',
#     'labels_url': 'https://api.github.com/repos/PennyDreadfulMTG/perf-reports/issues/52599/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/PennyDreadfulMTG/perf-reports/issues/52599/comments',
#     'events_url': 'https://api.github.com/repos/PennyDreadfulMTG/perf-reports/issues/52599/events',
#     'html_url': 'https://github.com/PennyDreadfulMTG/perf-reports/issues/52599',
#     'id': 530112007,
#     'node_id': 'MDU6SXNzdWU1MzAxMTIwMDc=',
#     'number': 52599,
#     'title': 'Exceeded slow_query limit (11.1 > 10.0) in mysql: ```',
#     'user': {'login': 'vorpal-buildbot',
#      'id': 23072004,
#      'node_id': 'MDQ6VXNlcjIzMDcyMDA0',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/23072004?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vorpal-buildbot',
#      'html_url': 'https://github.com/vorpal-buildbot',
#      'followers_url': 'https://api.github.com/users/vorpal-buildbot/followers',
#      'following_url': 'https://api.github.com/users/vorpal-buildbot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vorpal-buildbot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vorpal-buildbot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vorpal-buildbot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vorpal-buildbot/orgs',
#      'repos_url': 'https://api.github.com/users/vorpal-buildbot/repos',
#      'events_url': 'https://api.github.com/users/vorpal-buildbot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vorpal-buildbot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 958792189,
#       'node_id': 'MDU6TGFiZWw5NTg3OTIxODk=',
#       'url': 'https://api.github.com/repos/PennyDreadfulMTG/perf-reports/labels/decksite',
#       'name': 'decksite',
#       'color': 'bfd4f2',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-11-29T01:03:01Z',
#     'updated_at': '2019-11-29T01:03:01Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': '        SELECT\n            p.id,\n            LOWER(IFNULL(IFNULL(IFNULL(p.name, p.mtgo_username), p.mtggoldfish_username), p.tappedout_username)) AS name,\n            p.mtgo_username,\n            p.tappedout_username,\n            p.mtggoldfish_username,\n            p.discord_id,\n            p.elo,\n            p.locale\n        FROM\n            person AS p\n        WHERE\n            p.mtgo_username = \'thejacob\'\n    ```\n\n```[]``` (slow_query, 11.1, mysql)\n\nReported on decksite by mysql-perf\n\nLocation Hash: c7c409e2b8322e3f9ed89811ca2dd71e97bec5d0\n<details><summary><strong>Request Data</strong></summary>\n\n```\n\nRequest Method: GET\nPath: /people/thejacob/?locale=id\nCookies: {}\nEndpoint: person\nView Args: {\'person_id\': \'thejacob\'}\nPerson: logged_out\nReferrer: None\nRequest Data: {}\nHost: magic.vorpald20.com\nAccept-Encoding: gzip\nCf-Ipcountry: US\nX-Forwarded-For: 46.229.168.138, 172.68.141.234\nCf-Ray: 53d0a8846b88c1d4-SJC\nX-Forwarded-Proto: http\nCf-Visitor: {"scheme":"http"}\nAccept: text/html, application/rss+xml, application/atom+xml, text/xml, text/rss+xml\nUser-Agent: Mozilla/5.0 (compatible; SemrushBot/6~bl; +http://www.semrush.com/bot.html)\nCf-Connecting-Ip: 46.229.168.138\nCdn-Loop: cloudflare\nX-Forwarded-Host: magic.vorpald20.com\nX-Forwarded-Server: pennydreadfulmagic.com\nConnection: Keep-Alive\n```\n\n</details>\n\n'}},
#   'public': True,
#   'created_at': '2019-11-29T01:03:01Z',
#   'org': {'id': 22494209,
#    'login': 'PennyDreadfulMTG',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PennyDreadfulMTG',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22494209?'}},
#  {'id': '10972529835',
#   'type': 'ForkEvent',
#   'actor': {'id': 58128612,
#    'login': 'karthik2903',
#    'display_login': 'karthik2903',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/karthik2903',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58128612?'},
#   'repo': {'id': 187194716,
#    'name': 'skshiraj/Data-Science--Cheat-Sheet',
#    'url': 'https://api.github.com/repos/skshiraj/Data-Science--Cheat-Sheet'},
#   'payload': {'forkee': {'id': 224751964,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ3NTE5NjQ=',
#     'name': 'Data-Science--Cheat-Sheet',
#     'full_name': 'karthik2903/Data-Science--Cheat-Sheet',
#     'private': False,
#     'owner': {'login': 'karthik2903',
#      'id': 58128612,
#      'node_id': 'MDQ6VXNlcjU4MTI4NjEy',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/58128612?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/karthik2903',
#      'html_url': 'https://github.com/karthik2903',
#      'followers_url': 'https://api.github.com/users/karthik2903/followers',
#      'following_url': 'https://api.github.com/users/karthik2903/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/karthik2903/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/karthik2903/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/karthik2903/subscriptions',
#      'organizations_url': 'https://api.github.com/users/karthik2903/orgs',
#      'repos_url': 'https://api.github.com/users/karthik2903/repos',
#      'events_url': 'https://api.github.com/users/karthik2903/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/karthik2903/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/karthik2903/Data-Science--Cheat-Sheet',
#     'description': 'Cheat Sheets',
#     'fork': True,
#     'url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet',
#     'forks_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/forks',
#     'keys_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/teams',
#     'hooks_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/hooks',
#     'issue_events_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/events',
#     'assignees_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/tags',
#     'blobs_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/languages',
#     'stargazers_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/stargazers',
#     'contributors_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/contributors',
#     'subscribers_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/subscribers',
#     'subscription_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/subscription',
#     'commits_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/merges',
#     'archive_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/downloads',
#     'issues_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/karthik2903/Data-Science--Cheat-Sheet/deployments',
#     'created_at': '2019-11-29T01:03:00Z',
#     'updated_at': '2019-10-05T01:19:09Z',
#     'pushed_at': '2019-10-05T01:18:58Z',
#     'git_url': 'git://github.com/karthik2903/Data-Science--Cheat-Sheet.git',
#     'ssh_url': 'git@github.com:karthik2903/Data-Science--Cheat-Sheet.git',
#     'clone_url': 'https://github.com/karthik2903/Data-Science--Cheat-Sheet.git',
#     'svn_url': 'https://github.com/karthik2903/Data-Science--Cheat-Sheet',
#     'homepage': None,
#     'size': 232920,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-11-29T01:03:01Z'},
#  {'id': '10972529828',
#   'type': 'PushEvent',
#   'actor': {'id': 5514030,
#    'login': 'javastraat',
#    'display_login': 'javastraat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/javastraat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5514030?'},
#   'repo': {'id': 202132279,
#    'name': 'BM-Database/database-beta',
#    'url': 'https://api.github.com/repos/BM-Database/database-beta'},
#   'payload': {'push_id': 4333986747,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c32dc9bf308316fe9c654847aec8e64394963c41',
#    'before': 'fc858f21e367c7114a84ea3b60e77d5a7c630e81',
#    'commits': [{'sha': 'c32dc9bf308316fe9c654847aec8e64394963c41',
#      'author': {'email': 'javastraat@hotmail.com', 'name': 'Albert Einstein'},
#      'message': '<Ailunce HD1 BETA database *autogenerated* by pd2emc>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/BM-Database/database-beta/commits/c32dc9bf308316fe9c654847aec8e64394963c41'}]},
#   'public': True,
#   'created_at': '2019-11-29T01:03:01Z',
#   'org': {'id': 52372652,
#    'login': 'BM-Database',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/BM-Database',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52372652?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests

r = requests.get('https://cat-fact.herokuapp.com/facts')
r.text
# Out:
# '{"all":[{"_id":"5b4911940508220014ccfe94","text":"By the time a cat is 9 years old, it will only have been awake for three years of its life.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"58e008ad0aac31001185ed0c","text":"The frequency of a domestic cat\'s purr is the same at which muscles and bones repair themselves.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":5,"userUpvoted":null},{"_id":"59a60b8e6acf530020f3586e","text":"Cat owners are 17% more likely to have a graduate degree than non cat owners.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"58e008b80aac31001185ed0d","text":"Adult cats only meow to communicate with humans.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e009650aac31001185ed13","text":"In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00b2b0aac31001185ed1f","text":"A cat has five toes on his front paws, and four on the back, unless he\'s a polydactyl.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00be30aac31001185edfe","text":"Cats use their whiskers to detect if they can fit through a space.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00b4d0aac31001185ed22","text":"Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"5b199196ce456e001424256a","text":"Cats can distinguish different flavors in water.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b4912c60508220014ccfe99","text":"Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"58e007db0aac31001185ecf7","text":"There are cats who have survived falls from over 32 stories (320 meters) onto concrete.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e008800aac31001185ed07","text":"Wikipedia has a recording of a cat meowing, because why not?","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e009790aac31001185ed14","text":"The technical term for \\"hairball\\" is \\"bezoar.\\"","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e00a120aac31001185ed17","text":"A cat\'s brain is 90% similar to a human\'s — more similar than to a dog\'s.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"us ...

# %%
import requests

r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
r.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1730H075","WaterLevel": -999998},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2560H025","WaterLevel": 3.19},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1730H065","WaterLevel": 90.7},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2420H036","WaterLevel": 164.36},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1730H061","WaterLevel": 266.25},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2200H007","WaterLevel": 155.97},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2420H018","WaterLevel": 156.19},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2200H029","WaterLevel": 145.69},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1730H057","WaterLevel": 43.46},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1670H004","WaterLevel": 2.99},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1740H011","WaterLevel": 6.62},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2560H023","WaterLevel": 13.1},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2370H025","WaterLevel": 261.62},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1850H004","WaterLevel": 72.11},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1650H015","WaterLevel": 0.17},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2370H017","WaterLevel": 58.54},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1730H077","WaterLevel": 740.45},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2560H020","WaterLevel": 0.51},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1660H012","WaterLevel": 0.04},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1740H009","WaterLevel": 32.27},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1650H013","WaterLevel": 5.71},{"RecordTime": "Nov 29, 2019 8:20:00 AM","StationIdentifier": "1630H033","WaterLevel": -0.12},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2420H043","WaterLevel": 79.48},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1730H072","WaterLevel": 248.86},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2560H017","WaterLevel": 366.43},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2420H024","WaterLevel": 4.79},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1740H008","WaterLevel": 1.1},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1540H032","WaterLevel": 20.17},{"RecordTime": "Nov 29, 2019 8:20:00 AM","StationIdentifier": "1630H030","WaterLevel": 1.55},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1660H010","WaterLevel": 7.45},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1540H029","WaterLevel": 12.78},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2500H003","WaterLevel": 32.08},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2370H019","WaterLevel": 156.03},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1730H081","WaterLevel": -999998},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1730H068","WaterLevel": 10.14},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1630H025","WaterLevel": 1.43},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1650H010","WaterLevel": 0.03},{"RecordTime": "Nov 29, 2019 8:40:00 AM","StationIdentifier": "1510H083","WaterLevel": 116.61},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1650H012","WaterLevel": 0.69},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "2370H004","WaterLevel": 192.67},{"RecordTime": "Nov 29, 2019 8:50:00 AM","StationIdentifier": "1730H070","WaterLevel": 226.2},{"RecordTime": "Nov 29, 2019 8:50:0 ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
#
#
# [問卦] 我們是不是該捐口罩了啊？
#
#
# SuperDPP
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 SuperDPP 的文章
#
#
#  1/29
#
#
#
#
# 5
#
# [問卦] 中國學生是不是被民主化的很深?
#
#
# joy2105feh
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 joy2105feh 的文章
#
#
#  1/29
#
#
#
#
#
#
# Re: [新聞] 暗中參與中國千人計畫 哈佛大學化學系主
#
#
# Anddyliu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Anddyliu 的文章
#
#
#  1/29
#
#
#
#
#
#
# [問卦] 口罩店員用手分裝可以嗎？
#
#
# king665714
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 king665714 的文章
#
#
#  1/29
#
#
#
#
#
#
# Re: [爆卦] 中國網上謠傳病毒是美國的陰謀
#
#
# iamanidiot
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 iamanidiot 的文章
#
#
#  1/29
#
#
#
#
# 3
#
# [問卦] 寬鬆拉緊是現在的新流行????
#
#
# CavendishJr
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 CavendishJr 的文章
#
#
#  1/29
#
#
#
#
#
#
# Re: [新聞] 口罩荒主因 藥局業者：台商掃貨
#
#
# cloud72426
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cloud72426 的文章
#
#
#  1/29
#
#
#
#
# 1
#
# Re: [問卦] 范瑋琪在中國名聲很不好？
#
#
# demitri
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 demitri 的文章
#
#
#  1/29
#
#
#
#
# 5
#
# [新聞] 范挺中譙台狗官！張韶涵嗆黑白狗別亂叫
#
#
# britvic
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 britvic 的文章
#
#
#  1/29
#
#
#
#
# 2
#
# Re: [新聞] 口罩荒主因 藥局業者：台商掃貨
#
#
# Morrislakbay
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Morrislakbay 的文章
#
#
#  1/29
#
#
#
#
#
#
# [問卦] 有迷有蔡10紅衣女孩的八卦？
#
#
# Arthurseed
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Arthurseed 的文章
#
#
#  1/29
#
#
#
#
#
#
# Re: [問卦] 如果要找人來演KOBE的傳記電影該找誰？
#
#
# sky1119
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 sky1119 的文章
#
#
#  1/29
#
#
#
#
#
#
# [爆卦] 黑人轉po 幫助大陸等於幫助自己
#
#
# eatk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 eatk 的文章
#
#
#  1/29
#
#
#
#
#
#
# [問卦] 今天要回營當兵了 怕
#
#
# Moutza
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Moutza 的文章
#
#
#  1/29
#
#
#
#
#
#
# Re: [新聞] 冰球》創隊史新猷！ 台灣奪金牌成世界一
#
#
# Aotearoa
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Aotearoa 的文章
#
#
#  1/29
#
#
#
#
# 2
#
# [問卦] 歐陽娜娜 林心如 彭于晏怎麼看武漢肺炎
#
#
# silentknight
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 silentknight 的文章
#
#
#  1/29
#
#
#
#
#
#
# [問卦] 馬自達的車主是不是沒品特多啊
#
#
# zoosleep
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 zoosleep 的文章
#
#
#  1/29
#
#
#
#
#
#
#
# [公告] 八卦板板規(2019.08.21)
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  8/21
# !
#
#
#
# 58
#
# [公告] 請勿散佈錯假訊息
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  1/22
# M
#
#
#
# 5
#
# Fw: [徵求] 行車紀錄器 1/19 民生社區 下午五點半左
#
#
# maxjoiny
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 maxjoiny 的文章
#
#
#  1/26
#
#
#
#
# 18
#
# [公告] 因應武漢肺炎即時官方訊息暨討論區
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  1/25
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
#
#
# [問卦] 我們是不是該捐口罩了啊？
#
#
# SuperDPP
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 SuperDPP 的文章
#
#
#  1/29
#
#
#
#
# 5
#
# [問卦] 中國學生是不是被民主化的很深?
#
#
# joy2105feh
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 joy2105feh 的文章
#
#
#  1/29
#
#
#
#
#
#
# Re: [新聞] 暗中參與中國千人計畫 哈佛大學化學系主
#
#
# Anddyliu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Anddyliu 的文章
#
#
#  1/29
#
#
#
#
#
#
# [問卦] 口罩店員用手分裝可以嗎？
#
#
# king665714
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 king665714 的文章
#
#
#  1/29
#
#
#
#
#
#
# Re: [爆卦] 中國網上謠傳病毒是美國的陰謀
#
#
# iamanidiot
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 iamanidiot 的文章
#
#
#  1/29
#
#
#
#
# 3
#
# [問卦] 寬鬆拉緊是現在的新流行????
#
#
# CavendishJr
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 CavendishJr 的文章
#
#
#  1/29
#
#
#
#
#
#
# Re: [新聞] 口罩荒主因 藥局業者：台商掃貨
#
#
# cloud72426
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cloud72426 的文章
#
#
#  1/29
#
#
#
#
# 1
#
# Re: [問卦] 范瑋琪在中國名聲很不好？
#
#
# demitri
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 demitri 的文章
#
#
#  1/29
#
#
#
#
# 5
#
# [新聞] 范挺中譙台狗官！張韶涵嗆黑白狗別亂叫
#
#
# britvic
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 britvic 的文章
#
#
#  1/29
#
#
#
#
# 2
#
# Re: [新聞] 口罩荒主因 藥局業者：台商掃貨
#
#
# Morrislakbay
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Morrislakbay 的文章
#
#
#  1/29
#
#
#
#
#
#
# [問卦] 有迷有蔡10紅衣女孩的八卦？
#
#
# Arthurseed
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Arthurseed 的文章
#
#
#  1/29
#
#
#
#
#
#
# Re: [問卦] 如果要找人來演KOBE的傳記電影該找誰？
#
#
# sky1119
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 sky1119 的文章
#
#
#  1/29
#
#
#
#
#
#
# [爆卦] 黑人轉po 幫助大陸等於幫助自己
#
#
# eatk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 eatk 的文章
#
#
#  1/29
#
#
#
#
#
#
# [問卦] 今天要回營當兵了 怕
#
#
# Moutza
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Moutza 的文章
#
#
#  1/29
#
#
#
#
# 1
#
# Re: [新聞] 冰球》創隊史新猷！ 台灣奪金牌成世界一
#
#
# Aotearoa
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Aotearoa 的文章
#
#
#  1/29
#
#
#
#
# 2
#
# [問卦] 歐陽娜娜 林心如 彭于晏怎麼看武漢肺炎
#
#
# silentknight
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 silentknight 的文章
#
#
#  1/29
#
#
#
#
#
#
# [問卦] 馬自達的車主是不是沒品特多啊
#
#
# zoosleep
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 zoosleep 的文章
#
#
#  1/29
#
#
#
#
#
#
#
# [公告] 八卦板板規(2019.08.21)
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  8/21
# !
#
#
#
# 58
#
# [公告] 請勿散佈錯假訊息
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  1/22
# M
#
#
#
# 5
#
# Fw: [徵求] 行車紀錄器 1/19 民生社區 下午五點半左
#
#
# maxjoiny
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 maxjoiny 的文章
#
#
#  1/26
#
#
#
#
# 18
#
# [公告] 因應武漢肺炎即時官方訊息暨討論區
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  1/25
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36'}
cookies = {'logged_in': 'yes', 'user_session': 'L2myULHP3NDy5n07On053bgiFBdsDR6UUsKTdTsPN1Y583Zd'}
    
r = requests.get('https://github.com/new', headers=headers, cookies=cookies)
soup = BeautifulSoup(r.text, 'lxml')
soup.title # 加上檢查的 cookies ，就可以正確取得資料
# Out:
# <title>Sign in to GitHub · GitHub</title>
